# %%
import sys
import os

project_root = os.path.abspath('..')
if project_root not in sys.path:
    sys.path.append(project_root)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import warnings

from src.features import build_features
from src.visualization import visualize

warnings.filterwarnings('ignore')
sns.set_style()
plt.rcParams['figure.figsize'] = (12, 6)

# %%
df_procesada = pd.read_csv("../data/interim/datos_limpios.csv", encoding="latin-1", sep=";")

# %% [markdown]
# - Al hacer un analisis de las variables de Evolucion, se vio que estas tenian glosas demasiado
# extensan. Producto de lo anterior, se omitio el analisis explicito en este cuadernillo, ya que
# aumenta demasiado el tamano del archivo.
#
# - Solamente se analizara hasta la columna "Medicamentos".

# %%
visualize.analizar_distribucion_y_faltantes_variables(df_procesada.iloc[:, :50])
# Out:
# Analizando todas las variables numericas
#             n    EMBARAZO     Aborto     CIANOSIS  \
# count  3540.0  353.000000  44.000000  3441.000000
# mean      1.0    1.050992   1.272727     1.924441
# std       0.0    0.220293   0.499471     0.264330
# min       1.0    1.000000   0.000000     1.000000
# 25%       1.0    1.000000   1.000000     2.000000
# 50%       1.0    1.000000   1.000000     2.000000
# 75%       1.0    1.000000   2.000000     2.000000
# max       1.0    2.000000   2.000000     2.000000
#
#        HIPERTENSION ARTERIAL PULMONAR  INSUFICIENCIA CARDIACA
# count                     2604.000000             2580.000000
# mean                         1.927803                1.942248
# std                          0.258863                0.236619
# min                          1.000000                0.000000
# 25%                          2.000000                2.000000
# 50%                          2.000000                2.000000
# ...
